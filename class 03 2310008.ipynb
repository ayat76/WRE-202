# %%
#Comparison operator
A=20
B=40
C=40
print(A==B)
print(B==C)
print(A!=B)
print(A>=B)
print(A<=B)
# Out:
# False
# True
# True
# False
# True

# %%
#Logical Operator
""" and 
    or
    """

num=float(input("Insert a number:"))
logic=num>20 and num<30
print(logic)
# Out:
# Insert a number: 31
# False

# %%
num=float(input("Insert a number:"))
logic=num>20 or num<30
print(logic)
# Out:
# Insert a number: 15
# True

# %%
num=float(input("Enter a number"))
logic=not(num>50)
print(logic)
# Out:
# Enter a number 60
# False

# %%
#Assignment operator
A=20
B=30
A +=B
A -=B
A /=B
#A=A+B
print(A)
# Out:
# 0.6666666666666666

# %%
#Membership Operator
course="computer programming sessional - I"
Find= "computer" in course
print(Find)
# Out:
# True

# %%
#Identity Operator
A=15
B=15
C=A is B
print(C)
# Out:
# True

# %%
#Bitwise Operator
a=60 #0011 1100
b=13 #0000 1101
result=a & b # & works like and operator
print(result)
#a bit becomes 1 only if both bits are 1
#0011 1100
#0000 1101
#---------
#0000 1100 -> 12
result1=a|b # | works like or
print(result1)
# Out:
# 12
# 61

# %%
# Out:
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# enter a value 12
# enter a value 30
# False
# C:\Users\WRE 04\AppData\Local\Temp\ipykernel_4712\1416413758.py:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   D=C is 45

# %%
a=input("enter a value")
b=input("enter a value")
C=a+b
D= C is 45
print(D)
# Out:
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# enter a value 12
# enter a value 24
# False
# C:\Users\WRE 04\AppData\Local\Temp\ipykernel_4712\1416413758.py:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   D=C is 45
