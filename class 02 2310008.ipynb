# %%
print("wre23")
# Out:
# wre23 sucks

# %%
a="1234"
b=float(a)
c=int(a)
print(type(b))
print(type(c))
# Out:
# <class 'float'>
# <class 'int'>

# %%
NAME=input("Enter your name: ")
PIN=input("Enter your pin: ")
print(NAME)
print(PIN)
# Out:
# Enter your name:  sea
# Enter your pin:  1234
# sea
# 1234

# %%
NAME=(int(input("Enter your name:")))
print(NAME)
print(type(NAME))
# Out:
# Enter your name: 5555
# 5555
# <class 'int'>

# %%
#multiple input using split function
A,B,C,D=input().split()
print(A,"\n",B,"\n", C,"\n", D)
# Out:
#  sdf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 A,B,C,D=input().split()
#       2 print(A,"\n",B,"\n", C,"\n", D)
#
# ValueError: not enough values to unpack (expected 4, got 1)

# %%
#multiple input using input function
A,B=map(int, input("Enter two integer value").split())
print(A,B)
print(type(A))
print(type(B))
# Out:
# Enter two integer value 12 53533535
# 12 53533535
# <class 'int'>
# <class 'int'>

# %%
A,B=map(int, input("Enter two integer value").split())
C=A+B
print("The sum of",A,"and",B,"is",C)
# Out:
# Enter two integer value 5 9
# The sum of 5 and 9 is 14

# %%
A,B=map(int, input("Enter two integer value").split())
C=A+B
print("The sum of %d and %d is %d" %(A,B,C))
# Out:
# Enter two integer value 12 12
# The sum of 12 and 12 is 24

# %%
A=10
B=3
C=A/B
Remainder=A%B
print(Remainder)
print(C)
print(A)
print("The division of %f and %f is %f" %(A,B,C))
print("The division of %.2f and %.2f is %.2f"%(A,B,C))
# Out:
# 1
# 3.3333333333333335
# 10
# The division of 10.000000 and 3.000000 is 3.333333
# The division of 10.00 and 3.00 is 3.33
