# %% [markdown]
# # <div style="text-align: center;">Final Quiz</div>

# %% [markdown]
# Total Time: 60 min

# %% [markdown]
# ## Problem 1:  Write a program that:(05)
# * Takes marks in three subjects.
# * Calculates the average.
#
# ### Prints a performance category based on the average:
# * Average ≥ 80: Excellent
# * Average 60-79: Good
# * Average 40-59: Average
# * Average < 40: Poor

# %% [markdown]
# ## Problem 2: Write a python script for printing the even numbers from 1 to n using while loop. Take input(n) from users.(04)

# %% [markdown]
# ## Problem 3: Store the following monthly rainfall data (in mm) for a given year in a dictionary. (05)
#
#
# * January	: 85.4
# * February: 65.2
# * March	: 120.6
# * April	:140.3
# * May	    : 210.7
# * June	: 305.8
# * July	:420.5
# * August	:380.2
# * September:	290.6
# * October	:180.4
# * November :	95.8
# * December : 70.3
#
# Perform the following operations on this dictionary:
# •	Retrieve the rainfall value for July.
# •	Print the keys of the dictionary
# •	Print the values of the dictionary
# •	Print the type of the data frame
# •	Update the rainfall value of June (e.g., increase by 20 mm).

# %% [markdown]
# ## Problem 4: From the AQI dataset given to you, find out the following information:

# %% [markdown]
# ### 1. Calculate the maximum and minimum AQI value of Dhaka. (02)

# %% [markdown]
# ### 2. What is the mean AQI value of Dhaka?(02)

# %% [markdown]
# ### 3. How many times AQI value of Dhaka was between 100 and 150?(02)

# %% [markdown]
# ### 4.How many times air quality of Dhaka was very unhealthy?(02)

# %% [markdown]
# ### 5. Rename the column name of Dhaka to Pollution_Dhaka.(02)

# %% [markdown]
# ### 6. Drop these three columns Pollution Category, Pollution Category2 and Pollution Category3.(02)

# %% [markdown]
# ### 7. Assign a new dataframe with these columns Date, Pollution_Dhaka, Chattogram, Gazipur, and Narayanganj.(02)

# %% [markdown]
# ### 8. Perfrom data cleaning in the new dataset(05)
# * perform date-time formating
# * convert non-numric values to numeric
# * Use dropna or fillna
# * Do sorting if necessary

# %% [markdown]
# ### 9. Plot a **line graph** (Time vs AQI)  showing AQI values for Dhaka, chattogram, Gazipur and Narayanganj.(05)
# * Plot must have a title, xlablel, ylabel, legend, grid,
# * Rotate x-axis labels for clarity

# %% [markdown]
# ### 10. Save the plotted graph in png file format in the working directory(02)

# %% [markdown]
# ## Problem 5: These are the monthly rainfall data (in mm) for a given year: (05)
#
# * January	: 85.4
# * February: 65.2
# * March	: 120.6
# * April	:140.3
# * May	    : 210.7
# * June	: 305.8
# * July	:420.5
# * August	:380.2
# * September:	290.6
# * October	:180.4
# * November :	95.8
# * December : 70.3
#
# Plot a **bar graph** showing Time vs Rainfall.
# * Plot must have a title, xlablel, ylabel, legend, grid,
# * Rotate x-axis labels for clarity

# %%
_X=3

# %%
_x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 _x
#
# NameError: name '_x' is not defined
